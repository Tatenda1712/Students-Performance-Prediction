# %% [markdown]
# ## Student Performance Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns

# %%
categorical_cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
for i in categorical_cols:
    print(df[i].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import seaborn as sns

# %%
#plt.subplot(1,2,1)
sns.countplot(x="gender", order=['female','male'], data=df, palette="Set1")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="gender", order=['female','male'], hue="test preparation course", hue_order=['completed','none'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,1)
df['race/ethnicity'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="gender", order=['female','male'], hue="parental level of education", hue_order=["bachelor's degree", 'some college', "master's degree", "associate's degree",
 'high school', 'some high school'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="gender", order=['female','male'], hue="race/ethnicity", hue_order=['group B', 'group C', 'group A', 'group D', 'group E'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="gender", order=['female','male'], hue="lunch", hue_order=['standard', 'free/reduced'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="test preparation course", order=['completed','none'], hue="race/ethnicity", hue_order=['group B', 'group C', 'group A', 'group D', 'group E'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="test preparation course", order=['completed','none'], hue="parental level of education", hue_order=["bachelor's degree", 'some college', "master's degree", "associate's degree",
 'high school', 'some high school'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="parental level of education", order=["bachelor's degree", 'some college', "master's degree", "associate's degree",
 'high school', 'some high school'], hue="lunch", hue_order=['standard', 'free/reduced'], data=df, palette="muted")
plt.show()

# %%
#plt.subplot(1,2,2)
sns.countplot(x="test preparation course", order=['completed','none'], hue="lunch", hue_order=['standard', 'free/reduced'], data=df, palette="muted")
plt.show()

# %%
## Parental level of Education

# %%
#plt.subplot(1,2,2)
df['parental level of education'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
## Type of Lunch students take

# %%
#plt.subplot(1,2,2)
df['lunch'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %% [markdown]
# ## How many of the students take preparatory classes

# %%
#plt.subplot(1,2,2)
df['test preparation course'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
count_test = df['test preparation course'].value_counts()
labels = df['test preparation course'].value_counts().index
plt.figure(figsize= (6,6))
plt.pie(count_test,labels=labels,autopct='%1.1f%%')
plt.legend(labels)
plt.show()

# %%
df['average_score']=(df['math score']+df['reading score']+df['writing score'])/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ## Student performance in subjects based on gender

# %%
sns.scatterplot(x=df['average_score'],y=df['math score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='math score'>

# %%
sns.scatterplot(x=df['average_score'],y=df['reading score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='reading score'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
gender = {
    'male':1,
    'female':0
}

# %%
race = {
    'group A':0,
    'group B':1,
    'group C':2,
    'group D':3,
    'group E':4
}

# %%
df['gender']=df['gender'].map(gender)
df['race/ethnicity']=df['race/ethnicity'].map(race)

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0         0               1           bachelor's degree      standard
# 1         0               2                some college      standard
# 2         0               1             master's degree      standard
# 3         1               0          associate's degree  free/reduced
# 4         1               2                some college      standard
# ..      ...             ...                         ...           ...
# 995       0               4             master's degree      standard
# 996       1               2                 high school  free/reduced
# 997       0               2                 high school  free/reduced
# 998       0               3                some college      standard
# 999       0               3                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
level = {
    "bachelor's degree":0,
    'some college':1,
    "master's degree":2,
    "associate's degree":3,
    "high school":4,
    "some high school":5
}

# %%
df['parental level of education']=df['parental level of education'].map(level)

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education         lunch  \
# 0         0               1                            0      standard
# 1         0               2                            1      standard
# 2         0               1                            2      standard
# 3         1               0                            3  free/reduced
# 4         1               2                            1      standard
# ..      ...             ...                          ...           ...
# 995       0               4                            2      standard
# 996       1               2                            4  free/reduced
# 997       0               2                            4  free/reduced
# 998       0               3                            1      standard
# 999       0               3                            1  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  math score  \
# 0         0               1                            0          72
# 1         0               2                            1          69
# 2         0               1                            2          90
# 3         1               0                            3          47
# 4         1               2                            1          76
# ..      ...             ...                          ...         ...
# 995       0               4                            2          88
# 996       1               2                            4          62
# 997       0               2                            4          59
# 998       0               3                            1          68
# 999       0               3                            1          77
#
#      reading score  writing score  average_score  lunch_standard  \
# 0               72             74      72.666667               1
# ...

# %%
x = df.drop(columns='average_score').values

# %%
x
# Out:
# array([[ 0,  1,  0, ..., 74,  1,  1],
#        [ 0,  2,  1, ..., 88,  1,  0],
#        [ 0,  1,  2, ..., 93,  1,  1],
#        ...,
#        [ 0,  2,  4, ..., 65,  0,  0],
#        [ 0,  3,  1, ..., 77,  1,  0],
#        [ 0,  3,  1, ..., 86,  0,  1]], dtype=int64)

# %%
x[0]
# Out:
# array([ 0,  1,  0, 72, 72, 74,  1,  1], dtype=int64)

# %%
y = df['average_score'].values

# %%
y
# Out:
# array([ 72.66666667,  82.33333333,  92.66666667,  49.33333333,
#         76.33333333,  77.33333333,  91.66666667,  40.66666667,
#         65.        ,  49.33333333,  54.66666667,  45.        ,
#         73.        ,  73.33333333,  53.66666667,  74.        ,
#         87.66666667,  26.        ,  44.66666667,  57.66666667,
#         66.        ,  70.        ,  50.33333333,  71.66666667,
#         75.        ,  73.        ,  59.33333333,  70.33333333,
#         68.33333333,  69.        ,  72.33333333,  63.        ,
#         64.33333333,  40.        ,  88.66666667,  80.33333333,
#         79.33333333,  57.66666667,  84.33333333,  56.66666667,
#         56.66666667,  66.33333333,  58.66666667,  63.33333333,
#         53.33333333,  58.66666667,  60.66666667,  71.        ,
#         69.        ,  82.66666667,  52.        ,  71.33333333,
#         46.33333333,  80.33333333,  80.66666667,  39.        ,
#         84.33333333,  52.        ,  58.33333333,   9.        ,
# ...

# %%
corr = df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
##  Random Forest Regressor Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predictions=model.predict(x_test)

# %%
predictions
# Out:
# array([68.88      , 77.54      , 45.12      , 68.31666667, 74.03      ,
#        72.82333333, 69.97      , 44.06333333, 87.05333333, 38.19      ,
#        51.59      , 64.42      , 82.12      , 80.64666667, 54.09333333,
#        39.50333333, 53.44      , 86.35666667, 53.48      , 79.39333333,
#        62.79666667, 55.65      , 76.66      , 60.78333333, 47.68333333,
#        64.26      , 58.6       , 48.71333333, 63.00666667, 82.09333333,
#        79.79333333, 89.29333333, 89.04333333, 56.20333333, 55.07333333,
#        83.48666667, 96.96      , 59.17      , 72.09      , 72.07      ,
#        68.62      , 57.05666667, 70.24      , 72.18666667, 78.68666667,
#        58.41333333, 85.38333333, 61.68333333, 83.98333333, 57.62666667,
#        38.65      , 62.58      , 49.03      , 56.96      , 39.67666667,
#        70.39666667, 52.56333333, 64.37      , 77.96      , 60.90666667,
#        67.4       , 77.34      , 50.25      , 71.52333333, 65.47666667,
# ...

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(predictions,y_test))
# Out:
# 0.9975131434943671

# %%
import pickle
pickle.dump(model,open('Dataset.pkl','wb'))
